# %% [markdown]
# # YOLOv8 Binary Object Detection and Cropping Pipeline

# %% [markdown]
# ## Instructions on How to use this notebook:
# 1. Click on Runtime -> Change runtime type -> Click t4 GPU (this is the free option if you have paid subscription feel free to use other GPU)
#
# 2. Next Use the side to upload your image file
#
# 3. Replace path below with your image path. To do this use sidebar and right click on image file name ans select copy path. Paste this into `org_image` variable in the cell below and run the cell

# %%
org_img = "/content/W5_20220509_2_ST220182_A_JPG.rf.e306f0dc23897e2094b74be4951e684c.jpg"

# %% [markdown]
# Run the cell below to download the requirements and  model weights and install all required modules

# %%
# !pip install gdown
# !wget --no-check-certificate "https://drive.google.com/uc?export=download&id=1VAd8ZZJOVgIyhvx2uWxMaXBxJveJkddS" -O requirements.txt
# !gdown 1eul2LTjjFX4ye3QXn2l4fNP6Cz1ltUIx -O cls_model.keras
# !gdown 1IdQXwGsizccY9TSPiL2dMmVFUAZ58NRr -O detect_model.pt
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.7.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# --2025-07-21 23:44:24--  https://drive.google.com/uc?export=download&id=1VAd8ZZJOVgIyhvx2uWxMaXBxJveJkddS
# Resolving drive.google.com (drive.google.com)... 173.194.212.139, 173.194.212.101, 173.194.212.138, ...
# Connecting to drive.google.com (drive.google.com)|173.194.212.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1VAd8ZZJOVgIyhvx2uWxMaXBxJveJkddS&export=download [following]
# --2025-07-21 23:44:24--  https://drive.usercontent.google.com/download?id=1VAd8ZZJOVgIyhvx2uWxMaXBxJveJkddS&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.107.132, 2607:f8b0:400c:c32::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.107.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 768 [application/octet-stream]
# Saving to: ‘requirements.txt’
#
# requirements.txt    100%[===================>]     768  --.-KB/s    in 0s
#
# 2025-07-21 23:44:25 (34.0 MB/s) - ‘requirements.txt’ saved [768/768]
#
# Downloading...
# From (original): https://drive.google.com/uc?id=1eul2LTjjFX4ye3QXn2l4fNP6Cz1ltUIx
# From (redirected): https://drive.google.com/uc?id=1eul2LTjjFX4ye3QXn2l4fNP6Cz1ltUIx&confirm=t&uuid=c806d6f5-0990-493d-aa17-7dc54f283c6a
# To: /content/cls_model.keras
# 100% 290M/290M [00:02<00:00, 112MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1IdQXwGsizccY9TSPiL2dMmVFUAZ58NRr
# From (redirected): https://drive.google.com/uc?id=1IdQXwGsizccY9TSPiL2dMmVFUAZ58NRr&confirm=t&uuid=e531a93a-1ef5-42ae-a741-c60617ae3921
# To: /content/detect_model.pt
# 100% 117M/117M [00:00<00:00, 125MB/s]
# Requirement already satisfied: tensorflow==2.18.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (2.18.0)
# Requirement already satisfied: keras==3.8.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (3.8.0)
# Requirement already satisfied: torch==2.6.0+cu124 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (2.6.0+cu124)
# Requirement already satisfied: torchvision==0.21.0+cu124 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (0.21.0+cu124)
# Collecting nvidia-cuda-runtime-cu11==11.8.89 (from -r requirements.txt (line 11))
#   Downloading nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cudnn-cu11==9.10.2.21 (from -r requirements.txt (line 12))
#   Downloading nvidia_cudnn_cu11-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting ultralytics==8.3.168 (from -r requirements.txt (line 15))
#   Downloading ultralytics-8.3.168-py3-none-any.whl.metadata (37 kB)
# Collecting sahi==0.11.31 (from -r requirements.txt (line 18))
#   Downloading sahi-0.11.31-py3-none-any.whl.metadata (16 kB)
# Collecting pybboxes==0.1.6 (from -r requirements.txt (line 21))
#   Downloading pybboxes-0.1.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting pyyaml==6.0 (from -r requirements.txt (line 24))
#   Downloading PyYAML-6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 25)) (2.0.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 26)) (4.11.0.86)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (3.10.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 28)) (1.15.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 29)) (2.32.3)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 30)) (11.2.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (5.29.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (2.18.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.18.0->-r requirements.txt (line 2)) (0.37.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras==3.8.0->-r requirements.txt (line 3)) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras==3.8.0->-r requirements.txt (line 3)) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras==3.8.0->-r requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0+cu124->-r requirements.txt (line 6)) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0+cu124->-r requirements.txt (line 6)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0+cu124->-r requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0+cu124->-r requirements.txt (line 6)) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.6.0+cu124->-r requirements.txt (line 6))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.6.0+cu124->-r requirements.txt (line 6))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.6.0+cu124->-r requirements.txt (line 6))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.6.0+cu124->-r requirements.txt (line 6))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.6.0+cu124->-r requirements.txt (line 6))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.6.0+cu124->-r requirements.txt (line 6))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.6.0+cu124->-r requirements.txt (line 6))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.6.0+cu124->-r requirements.txt (line 6))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.6.0+cu124->-r requirements.txt (line 6))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0+cu124->-r requirements.txt (line 6)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0+cu124->-r requirements.txt (line 6)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0+cu124->-r requirements.txt (line 6)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.6.0+cu124->-r requirements.txt (line 6))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0+cu124->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0+cu124->-r requirements.txt (line 6)) (1.13.1)
# Collecting nvidia-cublas-cu11 (from nvidia-cudnn-cu11==9.10.2.21->-r requirements.txt (line 12))
#   Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.168->-r requirements.txt (line 15)) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.168->-r requirements.txt (line 15)) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.168->-r requirements.txt (line 15)) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics==8.3.168->-r requirements.txt (line 15)) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics==8.3.168->-r requirements.txt (line 15))
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from sahi==0.11.31->-r requirements.txt (line 18)) (8.2.1)
# Collecting fire (from sahi==0.11.31->-r requirements.txt (line 18))
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from sahi==0.11.31->-r requirements.txt (line 18)) (2.1.1)
# Collecting terminaltables (from sahi==0.11.31->-r requirements.txt (line 18))
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.6.0+cu124->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->-r requirements.txt (line 27)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->-r requirements.txt (line 27)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->-r requirements.txt (line 27)) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->-r requirements.txt (line 27)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->-r requirements.txt (line 27)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->-r requirements.txt (line 27)) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->-r requirements.txt (line 29)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->-r requirements.txt (line 29)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->-r requirements.txt (line 29)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->-r requirements.txt (line 29)) (2025.7.14)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.18.0->-r requirements.txt (line 2)) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics==8.3.168->-r requirements.txt (line 15)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics==8.3.168->-r requirements.txt (line 15)) (2025.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->-r requirements.txt (line 2)) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->-r requirements.txt (line 2)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->-r requirements.txt (line 2)) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.6.0+cu124->-r requirements.txt (line 6)) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras==3.8.0->-r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras==3.8.0->-r requirements.txt (line 3)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras==3.8.0->-r requirements.txt (line 3)) (0.1.2)
# Downloading nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux2014_x86_64.whl (875 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 22.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (397.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.1/397.1 MB 4.2 MB/s eta 0:00:00
# Downloading ultralytics-8.3.168-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.8 MB/s eta 0:00:00
# Downloading sahi-0.11.31-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 9.4 MB/s eta 0:00:00
# Downloading pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Downloading PyYAML-6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (757 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.9/757.9 kB 34.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 64.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.4 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl (417.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 3.6 MB/s eta 0:00:00
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=fb3adff6347fdcfd944a30cd4fd7f0597cf105c0bf59cf1584309faa19da00df
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# Installing collected packages: terminaltables, pyyaml, pybboxes, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cublas-cu11, fire, sahi, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cudnn-cu11, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed fire-0.7.0 nvidia-cublas-cu11-11.11.3.6 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu11-11.8.89 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu11-9.10.2.21 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pybboxes-0.1.6 pyyaml-6.0 sahi-0.11.31 terminaltables-3.1.10 ultralytics-8.3.168 ultralytics-thop-2.0.14

# %% [markdown]
# ## Run the script below runs the inference on the image.
# A summary of results is saved in `class_summary.csv` and the each image path, predicted class and confidence is saved in `detailed_predictions.csv`. Individual cropped images in their corresponding prdiction folders are save in `results`

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from collections import defaultdict
import csv
import pandas as pd
from sahi import AutoDetectionModel
from sahi.predict import get_sliced_prediction

# =======================
# 1. Load Classification Model
# =======================
if tf.config.list_physical_devices('GPU'):
    with tf.device('/GPU:0'):
        model_cls = load_model('/content/cls_model.keras')
else:
    model_cls = load_model('/content/cls_model.keras')

# =======================
# 2. Load Detection Model
# =======================
detection_model = AutoDetectionModel.from_pretrained(
    model_type="ultralytics",
    model_path='/content/detect_model.pt',
    confidence_threshold=0.2
)

# =======================
# 3. Get Sliced Prediction
# =======================
result = get_sliced_prediction(
    org_img,
    detection_model,
    slice_height=752,
    slice_width=752,
    overlap_height_ratio=0.3,
    overlap_width_ratio=0.3,
    postprocess_type="GREEDYNMM"
)

# =======================
# 4. Crop Prediction Boxes
# =======================
def crop_predictions_from_sahi(image_path, sahi_result, conf_thresh=0.05):
    img = cv2.imread(image_path)
    crops = []
    for obj in sahi_result.object_prediction_list:
        if obj.score.value < conf_thresh:
            continue
        x1, y1, x2, y2 = map(int, obj.bbox.to_xyxy())
        crop = img[y1:y2, x1:x2]
        crops.append(crop)
    return crops

def save_crops(crops, save_dir, base_filename="crop"):
    os.makedirs(save_dir, exist_ok=True)
    for idx, crop in enumerate(crops):
        save_path = os.path.join(save_dir, f"{base_filename}_{idx + 1}.jpg")
        cv2.imwrite(save_path, crop)
    print(f"{len(crops)} cropped images saved to {save_dir}")

crops = crop_predictions_from_sahi(org_img, result)
crop_dir = 'cropped_results'
save_crops(crops, save_dir=crop_dir, base_filename="insect")

# =======================
# 5. Classify with Thresholding and Save Results
# =======================
class_names = ['Caddisfly', 'Dipteran', 'Mayfly', 'Other', 'Stonefly', 'Terrestrial']
class_thresholds = {
    0: 0.4,   # Caddisfly
    1: 0.4,   # Dipteran
    2: 0.4,   # Mayfly
    3: 0.0,   # Other
    4: 0.4,   # Stonefly
    5: 0.4    # Terrestrial
}
OTHER_IDX = 3  # Index for "Other" class

img_size = (224, 224)
output_dir = "results"
os.makedirs(output_dir, exist_ok=True)
for class_name in class_names:
    os.makedirs(os.path.join(output_dir, class_name), exist_ok=True)

detailed_csv_path = "detailed_predictions.csv"
summary_csv_path = "class_summary.csv"
class_counts = defaultdict(int)

with open(detailed_csv_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Image Name', 'Raw Prediction', 'Confidence', 'Threshold', 'Final Prediction'])

    for file_name in os.listdir(crop_dir):
        if not file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
            continue

        img_path = os.path.join(crop_dir, file_name)
        img = image.load_img(img_path, target_size=img_size)
        img_array = image.img_to_array(img) / 255.0
        img_batch = np.expand_dims(img_array, axis=0)

        preds = model_cls.predict(img_batch)
        probs = preds[0]
        pred_idx = np.argmax(probs)
        raw_class = class_names[pred_idx]
        confidence = float(probs[pred_idx])
        threshold = class_thresholds.get(pred_idx, 0.5)

        # Apply threshold
        if confidence >= threshold:
            final_idx = pred_idx
            rerouted = False
        else:
            final_idx = OTHER_IDX
            rerouted = True

        final_class = class_names[final_idx]
        class_counts[final_class] += 1

        # Write to CSV
        writer.writerow([
            file_name,
            raw_class,
            round(confidence, 4),
            threshold,
            final_class
        ])

        # Save result image
        plt.figure()
        plt.imshow(img)
        plt.title(f"{final_class} ({confidence:.2f})")
        plt.axis('off')
        save_path = os.path.join(output_dir, final_class, f"{os.path.splitext(file_name)[0]}_pred.png")
        plt.savefig(save_path)
        plt.close()

        if rerouted:
            print(f"{file_name} → {raw_class} ({confidence:.2f}) ➡ rerouted to 'Other'")
        else:
            print(f"{file_name} → {final_class} ({confidence:.2f}) ✅")

# =======================
# 6. Save Summary CSV
# =======================
with open(summary_csv_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Class', 'Count'])
    for class_name in class_names:
        writer.writerow([class_name, class_counts[class_name]])

print(f"\nSummary CSV saved to: {summary_csv_path}")
print("Class Distribution:")
for cls, count in class_counts.items():
    print(f"{cls}: {count} times")
# Out:
# Performing prediction on 9 slices.
# 157 cropped images saved to cropped_results
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# insect_128.jpg → Dipteran (0.85) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# insect_74.jpg → Dipteran (0.89) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# insect_113.jpg → Dipteran (0.81) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# insect_40.jpg → Other (0.69) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# insect_66.jpg → Dipteran (0.68) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# insect_122.jpg → Dipteran (0.85) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# insect_103.jpg → Dipteran (0.71) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# insect_57.jpg → Dipteran (0.90) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# insect_96.jpg → Other (0.46) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# insect_29.jpg → Other (0.48) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# insect_63.jpg → Dipteran (0.91) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# insect_127.jpg → Dipteran (0.89) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# insect_5.jpg → Dipteran (0.54) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# insect_95.jpg → Other (0.66) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# insect_117.jpg → Other (0.79) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# insect_106.jpg → Dipteran (0.42) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# insect_151.jpg → Other (0.55) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# insect_47.jpg → Dipteran (0.91) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# insect_73.jpg → Other (0.81) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# insect_54.jpg → Dipteran (0.48) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# insect_145.jpg → Dipteran (0.86) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# insect_134.jpg → Dipteran (0.85) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# insect_110.jpg → Dipteran (0.88) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# insect_12.jpg → Dipteran (0.48) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# insect_64.jpg → Dipteran (0.90) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# insect_42.jpg → Other (0.88) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# insect_90.jpg → Dipteran (0.91) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# insect_28.jpg → Other (0.63) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# insect_152.jpg → Other (0.75) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# insect_46.jpg → Dipteran (0.77) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# insect_137.jpg → Dipteran (0.91) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# insect_41.jpg → Other (0.78) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# insect_87.jpg → Dipteran (0.91) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# insect_99.jpg → Dipteran (0.54) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# insect_22.jpg → Dipteran (0.94) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# insect_35.jpg → Dipteran (0.90) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# insect_67.jpg → Dipteran (0.85) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# insect_118.jpg → Dipteran (0.92) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# insect_92.jpg → Dipteran (0.85) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# insect_155.jpg → Other (0.52) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_146.jpg → Other (0.76) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# insect_135.jpg → Other (0.69) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# insect_102.jpg → Dipteran (0.92) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# insect_44.jpg → Dipteran (0.92) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# insect_62.jpg → Dipteran (0.89) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# insect_15.jpg → Dipteran (0.85) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# insect_105.jpg → Dipteran (0.89) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# insect_11.jpg → Other (0.72) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# insect_8.jpg → Dipteran (0.87) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# insect_17.jpg → Other (0.84) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# insect_140.jpg → Dipteran (0.91) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# insect_34.jpg → Other (0.56) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# insect_80.jpg → Dipteran (0.87) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# insect_132.jpg → Dipteran (0.85) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# insect_131.jpg → Dipteran (0.89) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_48.jpg → Dipteran (0.85) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# insect_83.jpg → Dipteran (0.90) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# insect_7.jpg → Other (0.87) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# insect_52.jpg → Terrestrial (0.49) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# insect_104.jpg → Other (0.86) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# insect_4.jpg → Dipteran (0.89) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# insect_136.jpg → Dipteran (0.93) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# insect_50.jpg → Other (0.77) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# insect_2.jpg → Caddisfly (0.50) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# insect_1.jpg → Dipteran (0.85) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_16.jpg → Terrestrial (0.70) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# insect_59.jpg → Dipteran (0.90) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# insect_101.jpg → Dipteran (0.67) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# insect_124.jpg → Other (0.82) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# insect_32.jpg → Dipteran (0.90) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# insect_91.jpg → Dipteran (0.90) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# insect_33.jpg → Other (0.87) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_65.jpg → Dipteran (0.88) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# insect_93.jpg → Dipteran (0.92) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# insect_60.jpg → Other (0.53) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# insect_25.jpg → Dipteran (0.91) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# insect_109.jpg → Other (0.73) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# insect_154.jpg → Other (0.72) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# insect_142.jpg → Other (0.85) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# insect_75.jpg → Dipteran (0.47) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# insect_45.jpg → Dipteran (0.40) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# insect_141.jpg → Other (0.56) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# insect_112.jpg → Other (0.55) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# insect_115.jpg → Other (0.84) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# insect_51.jpg → Dipteran (0.87) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_6.jpg → Dipteran (0.89) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_150.jpg → Other (0.69) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_88.jpg → Dipteran (0.91) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# insect_133.jpg → Dipteran (0.40) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# insect_84.jpg → Dipteran (0.54) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# insect_121.jpg → Dipteran (0.89) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# insect_69.jpg → Dipteran (0.73) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# insect_13.jpg → Dipteran (0.92) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# insect_130.jpg → Dipteran (0.88) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_157.jpg → Other (0.40) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# insect_72.jpg → Dipteran (0.31) ➡ rerouted to 'Other'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# insect_85.jpg → Dipteran (0.68) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# insect_19.jpg → Dipteran (0.80) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# insect_37.jpg → Dipteran (0.91) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_81.jpg → Dipteran (0.71) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# insect_82.jpg → Dipteran (0.93) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# insect_94.jpg → Dipteran (0.91) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# insect_3.jpg → Other (0.91) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# insect_156.jpg → Other (0.81) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# insect_43.jpg → Dipteran (0.91) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# insect_30.jpg → Dipteran (0.56) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# insect_70.jpg → Other (0.49) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_21.jpg → Other (0.44) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# insect_119.jpg → Dipteran (0.91) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# insect_23.jpg → Dipteran (0.41) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_68.jpg → Dipteran (0.48) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# insect_24.jpg → Other (0.91) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# insect_36.jpg → Dipteran (0.92) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# insect_97.jpg → Dipteran (0.76) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# insect_116.jpg → Other (0.89) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# insect_18.jpg → Dipteran (0.83) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# insect_49.jpg → Other (0.50) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# insect_39.jpg → Dipteran (0.61) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# insect_100.jpg → Dipteran (0.71) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# insect_27.jpg → Dipteran (0.89) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# insect_76.jpg → Dipteran (0.88) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# insect_120.jpg → Dipteran (0.89) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_129.jpg → Dipteran (0.63) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# insect_71.jpg → Dipteran (0.84) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# insect_26.jpg → Other (0.86) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# insect_79.jpg → Dipteran (0.90) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# insect_14.jpg → Dipteran (0.42) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# insect_138.jpg → Terrestrial (0.74) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_147.jpg → Dipteran (0.90) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_149.jpg → Other (0.77) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# insect_148.jpg → Dipteran (0.91) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_56.jpg → Dipteran (0.90) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_61.jpg → Dipteran (0.83) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# insect_114.jpg → Dipteran (0.90) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# insect_125.jpg → Other (0.51) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# insect_89.jpg → Other (0.62) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# insect_111.jpg → Other (0.55) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# insect_153.jpg → Dipteran (0.94) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_78.jpg → Other (0.44) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# insect_55.jpg → Dipteran (0.87) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# insect_144.jpg → Other (0.93) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# insect_53.jpg → Dipteran (0.55) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# insect_139.jpg → Other (0.62) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# insect_9.jpg → Dipteran (0.89) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# insect_108.jpg → Other (0.45) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# insect_107.jpg → Dipteran (0.87) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# insect_31.jpg → Dipteran (0.91) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# insect_86.jpg → Dipteran (0.47) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_98.jpg → Dipteran (0.92) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# insect_123.jpg → Dipteran (0.85) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# insect_10.jpg → Dipteran (0.92) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# insect_38.jpg → Dipteran (0.84) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# insect_58.jpg → Dipteran (0.88) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# insect_20.jpg → Dipteran (0.92) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# insect_77.jpg → Dipteran (0.90) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# insect_143.jpg → Dipteran (0.64) ✅
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# insect_126.jpg → Other (0.87) ✅
#
# Summary CSV saved to: class_summary.csv
# Class Distribution:
# Dipteran: 104 times
# Other: 49 times
# Terrestrial: 3 times
# Caddisfly: 1 times
# Mayfly: 0 times
# Stonefly: 0 times

# %% [markdown]
# ## Run cell below to download csv files and image prediction folder

# %%
from google.colab import files

# Download csv files
files.download('/content/detailed_predictions.csv')
files.download('/content/class_summary.csv')

#Download image folder
import shutil

# Zip the folder
shutil.make_archive('/content/results', 'zip', '/content/results')

# Download the zip file
files.download('/content/results.zip')

# %% [markdown]
# ## Want to run inference with another image? Run cell below to clear out current results.

# %%
# !rm -rf /content/cropped_results
# !rm -rf /content/results/
# !rm -rf /content/detailed_predictions.csv
# !rm -rf /content/class_summary.csv
# !rm -rf /content/results.zip
